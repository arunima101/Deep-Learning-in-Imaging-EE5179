# %% [markdown]
# ### Loading MNIST Data

# %%
#Importing the necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import Dataloader as dl
import activations

# %%
train_data,train_label,test_data,test_label=dl.load_data() #Loading the data, the labels have been converted to one-hot-vector
# Out:
# /home/arunima/anaconda3/envs/EE5179/lib/python3.10/site-packages/torchvision/datasets/mnist.py:65: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# /home/arunima/anaconda3/envs/EE5179/lib/python3.10/site-packages/torchvision/datasets/mnist.py:70: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")

# %%
import neuralnetwork as nn

# %%
output=nn.training_nn(train_data,train_label,[784,500,250,100,10],64,0.01,15,'sigmoid')

# %%
output[1]
# Out:
# {(0, 1): 2.6335503974658456,
#  (0, 2): 2.450552012460801,
#  (0, 3): 2.477647810273923,
#  (0, 4): 2.460738669755308,
#  (0, 5): 2.5418436659630794,
#  (0, 6): 2.468526913231403,
#  (0, 7): 2.3944392327319974,
#  (0, 8): 2.784015779839772,
#  (0, 9): 2.468010166755783,
#  (0, 10): 2.707702334755138,
#  (0, 11): 2.6858636343211684,
#  (0, 12): 2.515707798926247,
#  (0, 13): 2.447043865006367,
#  (0, 14): 2.54947006139723,
#  (0, 15): 2.442636881628446,
#  (1, 16): 2.5774915555610276,
#  (1, 17): 2.4293066259144234,
#  (1, 18): 2.370088269376549,
#  (1, 19): 2.4000075721112824,
#  (1, 20): 2.5781435623032474,
#  (1, 21): 2.4829882361233677,
#  (1, 22): 2.5757800569156046,
#  (1, 23): 2.4755436672927034,
#  (1, 24): 2.8352425223006437,
#  (1, 25): 2.528012121497168,
#  (1, 26): 2.375751562076945,
#  (1, 27): 2.4248952138141084,
#  (1, 28): 2.4959783424255724,
#  (1, 29): 2.446801923321412,
#  (1, 30): 2.563311196501486,
#  (1, 31): 2.5779671766834924,
#  (2, 32): 2.6198796857809987,
# ...

# %%
output[0]
# Out:
# [[0, 2.605984252338977],
#  [1, 2.758808454288571],
#  [2, 2.3746697870217695],
#  [3, 2.578814546567015],
#  [4, 2.5379112918009055],
#  [5, 2.4589246444500232],
#  [6, 2.478026157086127],
#  [7, 2.534126858673733],
#  [8, 2.598164740083778],
#  [9, 2.5654568020214117],
#  [10, 2.5830557437695143],
#  [11, 2.494555930237623],
#  [12, 2.418765498485567],
#  [13, 2.7541862300020368],
#  [14, 2.487573372559271]]
